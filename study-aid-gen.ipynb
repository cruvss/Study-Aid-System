# %%
import os
import numpy as np
from openai import OpenAI
from typing import Optional
import json

# %%
from typing import Optional
from openai import OpenAI

class ResponseGenerator:
    def __init__(
        self, 
        api_key: str, 
        base_url: str = "https://openrouter.ai/api/v1",
    ):
        self.client = OpenAI(
            base_url=base_url,
            api_key=api_key
        )

    def generate_response(self, prompt: str, topic: str, grade_level: str, language: str, model: str = "perplexity/sonar") -> Optional[str]:
        """
        Generate structured and engaging facts about the topic for the specified grade level,
        with tone definitions for TTS (Text-to-Speech) conversion.
        """
        try:
            print(f"Prompt: {prompt}")

            completion = self.client.chat.completions.create(
                model=model,
                messages=[
                    {
                        "role": "system",
                        "content": """You are an expert educator who provides explanations tailored to students based on specified grade levels. 
                        Each explanation should be engaging, structured, and appropriate for the given grade level in their specified language."""
                    },
                    {
                        "role": "user",
                        "content": prompt
                    }
                ]
            )

          
            print("API Response:", completion)

 
            if completion and hasattr(completion, "choices") and completion.choices:
                return completion.choices[0].message.content
            
            print("Error: No valid response from API.")
            return None
        
        except Exception as e:
            print(f"Error generating response: {str(e)}")
            return None

def generate_facts(topic: str,idx:int ,custom_prompt:str ,grade_level: str,language:str,api_key: str) -> str:
    """
    Process the topic and grade level to generate structured facts with tone definitions for TTS.
    
    Args:
        topic (str): The topic for the facts
        grade_level (str): The grade level of the student
        api_key (str): API key for OpenRouter
        
    Returns:
        str: Structured facts with tone definitions
    """
    prompts = [f"\n\nTopic: {topic}\nGrade Level: {grade_level}\n\nProvide explanation for given topic of {topic} and for grade level {grade_level} in {language} language.",
               f"\n\nTopic: {topic}\nGrade Level: {grade_level}\n\nProvide an elaborate curriculum equations with real-life examples,(if available) for topic {topic} and grade level {grade_level} in {language} language.",
               f"\n\nTopic: {topic}\nGrade Level: {grade_level}\n\nProvide an elaborate different use cases for topic {topic} and grade level {grade_level} at certain fields and in {language} language.",
               f"\n\nTopic: {topic}\nGrade Level: {grade_level}\n\nProvide most probable objective-type questions along with answers related to the topic (5 questions, tough and medium range, closely aligned with the National Testing Agency’s (NTA) approach for NEET exam questions) for topic {topic} and grade level {grade_level} and in {language} language.",
               f"\n\nTopic: {topic}\nGrade Level: {grade_level}\n\nProvide all questions and answers from the past 10 years of NEET question papers related to the topic for topic {topic} and grade level {grade_level} at certain fields and in {language} language."]
    
    prompts += custom_prompt
    
    response_gen = ResponseGenerator(
        api_key=api_key
    )

    if idx==None:
        out=[]
        for prompt in prompts:
            out+=[response_gen.generate_response(prompt,topic, grade_level , language)]

# %%
class ResponseGenerator:
    def __init__(
        self, 
        api_key: str, 
        base_url: str = "https://openrouter.ai/api/v1",
    ):
        self.client = OpenAI(
            base_url=base_url,
            api_key=api_key
        )

    def generate_response(self, prompt:str,topic: str, grade_level: str, language:str, model: str = "openai/gpt-4o-mini") -> Optional[str]:
        """
        Generate structured and engaging facts about the topic for the specified grade level,        """
        try:
           
         
            
            print(prompt)


            completion = self.client.chat.completions.create(
                model=model,
                messages=[
                    {
                        "role": "system",
                        "content": """You are an expert educator who provides explanation tailored to students based on specified grade levels. 
                        Each explanation should be engaging, structured, and appropriate for the given grade level in their specified language."""
                    },
                    {
                        "role": "user",
                        "content": prompt
                    }
                ]
            )
            
            return completion.choices[0].message.content
            
        except Exception as e:
            print(f"Error generating response: {str(e)}")
            return None

def generate_facts(topic: str,idx:int ,custom_prompt:str,subject:str ,grade_level: str,language:str,api_key: str) -> str:
    """
    Process the topic and grade level to generate structured facts with tone definitions for TTS.
    
    Args:
        topic (str): The topic for the facts
        grade_level (str): The grade level of the student
        api_key (str): API key for OpenRouter
        
    Returns:
        str: Structured facts with tone definitions
    """
    prompts = [f"\n\nGrade Level: {grade_level}\nSubject: {subject} \nTopic: {topic} \n\nProvide explanation for given topic of {topic} from subject {subject} and for grade level {grade_level} in {language} language.",
               f"\n\nGrade Level: {grade_level}\nSubject: {subject} \nTopic: {topic} \n\nProvide an elaborate curriculum equations with real-life examples,(if available) for topic {topic} from subject {subject} and grade level {grade_level} in {language} language.",
               f"\n\nGrade Level: {grade_level}\nSubject: {subject} \nTopic: {topic} \n\nProvide an elaborate different use cases for topic {topic} from subject {subject} and grade level {grade_level} at certain fields and in {language} language.",
               f"\n\nGrade Level: {grade_level}\nSubject: {subject} \nTopic: {topic} \n\nProvide most probable objective-type questions along with answers related to the topic (5 questions, tough and medium range, closely aligned with the National Testing Agency’s (NTA) approach for NEET exam questions) for topic {topic} from subject {subject} and grade level {grade_level} and in {language} language.",
               f"\n\nGrade Level: {grade_level}\nSubject: {subject} \nTopic: {topic} \n\nProvide all questions and answers from the past 10 years of NEET question papers related to the topic for topic {topic}from subject {subject} and grade level {grade_level} at certain fields and in {language} language."]
    
    prompts += custom_prompt
    
    response_gen = ResponseGenerator(
        api_key=api_key
    )

    if idx==None:
        out=[]
        for prompt in prompts:
            out+=[response_gen.generate_response(prompt,topic, grade_level , language)]
        return out
        
    return response_gen.generate_response(prompts[idx],topic, grade_level , language) or ""

# %%
topic = "Laws of Motion"
grade_level = "12"
api_key = "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"
language='English'
subject='physics'
custom_prompt=[f'\n\nGrade Level: {grade_level}\nSubject: {subject} \nTopic: {topic}\n\n Provide jokes for topic {topic} from subject {subject} and grade level {grade_level} in {language} language.']

response = generate_facts(topic=topic, idx=None, custom_prompt=custom_prompt ,subject=subject, grade_level=grade_level,language=language, api_key=api_key)
# Out:
# Grade Level: 12
# Subject: physics
# Topic: Laws of Motion
#
# Provide explanation for given topic of Laws of Motion from subject physics and for grade level 12 in English language.
#
#
# Grade Level: 12
# Subject: physics
# Topic: Laws of Motion
#
# Provide an elaborate curriculum equations with real-life examples,(if available) for topic Laws of Motion from subject physics and grade level 12 in English language.
#
#
# Grade Level: 12
# Subject: physics
# Topic: Laws of Motion
#
# Provide an elaborate different use cases for topic Laws of Motion from subject physics and grade level 12 at certain fields and in English language.
#
#
# Grade Level: 12
# Subject: physics
# Topic: Laws of Motion
#
# Provide most probable objective-type questions along with answers related to the topic (5 questions, tough and medium range, closely aligned with the National Testing Agency’s (NTA) approach for NEET exam questions) for topic Laws of Motion from subject physics and grade level 12 and in English language.
#
#
# Grade Level: 12
# Subject: physics
# Topic: Laws of Motion
#
# Provide all questions and answers from the past 10 years of NEET question papers related to the topic for topic Laws of Motionfrom subject physics and grade level 12 at certain fields and in English language.
#
#
# Grade Level: 12
# Subject: physics
# Topic: Laws of Motion
#
#  Provide jokes for topic Laws of Motion from subject physics and grade level 12 in English language.

# %%
for i in range(6):
    print(response[i])
# Out:
# ## Understanding the Laws of Motion
#
# The Laws of Motion, formulated by Sir Isaac Newton in the 17th century, are fundamental principles that describe the relationship between the motion of an object and the forces acting on it. These laws are pivotal in understanding both classical mechanics and everyday phenomena. Let’s break them down.
#
# ### Newton’s First Law: The Law of Inertia
#
# **Definition:** An object at rest stays at rest, and an object in motion remains in motion with the same speed and in the same direction unless acted upon by a net external force.
#
# **Explanation:** This law introduces the concept of inertia, which is an object's resistance to change in its state of motion. For example, if you slide a book on a table, it eventually stops due to the force of friction, but without friction, it would continue moving uniformly forever. Think about how when you're in a car that suddenly stops, your body lurches forward; that’s inertia in action!
#
# ### Newton’s Second Law: The Law of Acceleration
#
# **Definition:** The acceleration of an object is directly proportional to the net force acting upon it and inversely proportional to its mass. This can be expressed with the formula:
# \[ F = ma \]
# where \( F \) is the net force, \( m \) is mass, and \( a \) is acceleration.
#
# **Explanation:** This law quantifies how the motion of an object changes when forces act upon it. For instance, if you kick a soccer ball (applying a force), it accelerates in the direction of the kick. The greater the force, the greater the acceleration. Conversely, if the ball were much heavier (greater mass), it would accelerate less in response to the same force.
#
# ### Newton’s Third Law: The Law of Action-Reaction
#
# **Definition:** For every action, there is an equal and opposite reaction.
#
# **Explanation:** This law emphasizes that forces always occur in pairs. When you push against a wall, the wall pushes back with an equal force. This is why you don't go through the wall! A practical example is when a rocket launches: the engines expel gas downwards, and the reaction force pushes the rocket upwards.
#
# ### Applications and Implications
#
# 1. **Daily Life:** Understanding motion in vehicles, sports, or even when walking. For example, wearing seatbelts in cars is crucial because of the first law—if the car stops suddenly, your body continues moving at its former speed, risking injury.
#
# 2. **Engineering:** Engineers consider these laws when designing vehicles, buildings, and much more. They calculate forces to ensure structures can withstand loads and that vehicles perform safely.
#
# 3. **Space Exploration:** Newton’s laws allow scientists to plot trajectories for spacecraft, ensuring they reach their destinations by accounting for forces such as gravity and thrust.
#
# ### Final Thoughts
#
# Grasping Newton's Laws of Motion provides deep insights into how the universe behaves. Whether you're launching a rocket or simply playing sports, these principles govern the physical world around you. As you continue your studies in physics, consider how these laws interact and apply to complex systems, laying the groundwork for more advanced topics in physics.
# ### Laws of Motion Curriculum: Grade 12 Physics
#
# #### Overview
#
# The Laws of Motion, formulated by Sir Isaac Newton, form the foundation of classical mechanics. They describe the relationship between a body and the forces acting upon it, and the motion of the body in response to those forces. In this curriculum, we will explore Newton's three laws, their mathematical expressions, and provide real-life examples to illustrate their applications.
#
# ---
#
# ### Newton's First Law of Motion
#
# **Statement**: An object at rest stays at rest, and an object in motion stays in motion with the same speed and in the same direction unless acted upon by a net external force.
#
# **Equation**:
# \[ F_{\text{net}} = 0 \Rightarrow \Delta v = 0 \] (The change in velocity \(\Delta v\) is zero if the net force \(F_{\text{net}}\) is zero).
#
# **Real-life Example**:
# Consider a book resting on a table. The book will not move unless someone applies a force to it (like pushing it). Similarly, if you slide the book on the table, it keeps moving until friction (an external force) slows it down.
#
# ---
#
# ### Newton's Second Law of Motion
#
# **Statement**: The acceleration of an object is directly proportional to the net force acting on it and inversely proportional to its mass.
#
# **Equation**:
# \[ F_{\text{net}} = m \cdot a \]
# Where:
# - \(F_{\text{net}}\) = net force acting on the object (in Newtons, N)
# - \(m\) = mass of the object (in kilograms, kg)
# - \(a\) = acceleration (in meters per second squared, m/s²)
#
# **Real-life Example**:
# If you push a shopping cart (with a mass of 10 kg) at a force of 20 N, you can calculate its acceleration:
#
# \[
# a = \frac{F_{\text{net}}}{m} = \frac{20 \, \text{N}}{10 \, \text{kg}} = 2 \, \text{m/s}^2
# \]
#
# This means the cart will accelerate at \(2 \, \text{m/s}^2\). If you put more groceries (increasing the mass), you would need to apply more force to achieve the same acceleration.
#
# ---
#
# ### Newton's Third Law of Motion
#
# **Statement**: For every action, there is an equal and opposite reaction.
#
# **Equation**:
# If object A exerts a force on object B, then object B exerts a force on object A of equal magnitude but in the opposite direction.
# \[ F_{AB} = -F_{BA} \]
#
# **Real-life Example**:
# When you jump off a small boat onto the dock, you push down and back on the boat (action). In response, the boat pushes you in the opposite direction (reaction), causing it to move backward even as you leap forward.
#
# ---
#
# ### Summary of Laws Illustrated
#
# 1. **First Law**: A football remains on the ground until someone kicks it.
# 2. **Second Law**: A heavier car requires more force to accelerate compared to a lighter car when both are pushed with the same force.
# 3. **Third Law**: Swimmers push the water backward to propel themselves forward in the pool.
#
# ---
#
# ### Assessment Ideas
#
# - **Conceptual Questions**: Explain how each law applies in a car crash scenario.
# - **Mathematical Problems**: Calculate the force required to accelerate a bicycle of known mass at a specified rate.
# - **Experiments**: Design an experiment to demonstrate Newton's third law using different types of balls.
#
# ---
#
# ### Conclusion
#
# Understanding Newton's Laws of Motion not only helps us understand the fundamentals of physics but also allows us to analyze and predict the motion of objects in our everyday lives. From cars on a road to athletes in sports, these laws govern the physical world around us. Through equations and real-life applications, students can appreciate the importance of these principles in both theoretical and practical contexts.
# Certainly! The Laws of Motion, formulated by Sir Isaac Newton, are fundamental principles that describe the relationship between the motion of an object and the forces acting upon it. Here are several use cases illustrating their applications across various fields:
#
# ### 1. **Engineering and Design**
#    - **Bridge Engineering**: Engineers use Newton’s laws to calculate the forces acting on bridges. For instance, the first law (inertia) helps in understanding how bridges resist or move under applied forces like wind or vehicle load. The second law (F=ma) is utilized to determine how much weight the structure can safely hold.
#    - **Automotive Engineering**: Design of vehicles involves understanding motion. Engineers apply all three laws to calculate acceleration, braking force, and crash safety features. For example, during a crash, the third law explains how the force exerted on passengers by the car is equal to the force they exert back, which informs safety designs.
#
# ### 2. **Aerospace**
#    - **Rocket Propulsion**: The laws of motion are critical in understanding the dynamics of rockets. The second law governs how rockets are propelled; the thrust generated by expelling gas downwards results in an upward motion (third law). This principle is used to calculate launch trajectories and control satellite movements.
#
# ### 3. **Sports Science**
#    - **Athletics Performance**: Coaches analyze athletes' movements using Newton’s laws to improve performance. For example, understanding how the forces generated by sprinters can maximize acceleration (second law) or how an athlete uses force to strike a ball (third law) helps in refining techniques.
#    - **Sports Equipment Design**: The design of equipment, like golf clubs or tennis rackets, incorporates these laws to enhance performance and safety. Engineers analyze how the shape and construction influence motion, optimizing how forces are transmitted to the ball.
#
# ### 4. **Astronomy and Space Exploration**
#    - **Planetary Motion**: Newton’s laws help in modeling the motion of planets and celestial bodies. The law of universal gravitation, stemming from his second law, explains how planets orbit stars and how spacecraft navigate between planets and moons based on gravitational forces.
#    - **Satellite Deployment**: The laws of motion are crucial in deploying satellites into orbit. Engineers calculate the necessary velocity (using the second law) to escape Earth's gravity and the adjustments needed for maintaining a stable orbit.
#
# ### 5. **Robotics**
#    - **Robotic Arm Design**: Robotics relies on the laws of motion to control movements with precision. The concepts of force and mass (second law) are used to determine how much weight a robotic arm can handle and how quickly it can move without losing stability.
#    - **Autonomous Vehicles**: In the development of self-driving cars, the laws of motion are applied to analyze the dynamics of the vehicle in various driving conditions, ensuring safety and efficiency in navigation.
#
# ### 6. **Biomechanics**
#    - **Human Movement Analysis**: Understanding human biomechanics involves applying Newton's laws to study how forces act during activities like walking or jumping. For example, the second law helps in analyzing the acceleration produced by leg muscles when pushing off the ground.
#
# ### 7. **Environmental Science**
#    - **Pollutant Dispersion**: In environmental studies, Newton's laws explain how pollutants disperse in air or water. The second law assists in modeling how different variables (like mass and force) affect the spread of contaminants during spills or emissions.
#
# ### Conclusion
# The Laws of Motion have extensive applications across different fields, showcasing their versatility and importance in solving real-world problems. By understanding these principles, professionals in various domains can innovate, design, and improve systems that are integral to our daily lives. Whether it’s engineering safe structures, launching rockets, analyzing sports performance, or designing efficient robots, Newton’s laws remain fundamental to our comprehension of motion and interaction in the universe.
# Here are five objective-type questions related to the topic of Laws of Motion, designed for Grade 12 Physics students and aligned with the NEET exam approach by the National Testing Agency (NTA). Each question has one correct answer provided.
#
# ### Questions
#
# 1. **A 5 kg block is pulled on a frictionless surface by a constant force of 10 N. What is the acceleration of the block?**
#    a) 1 m/s²
#    b) 2 m/s²
#    c) 5 m/s²
#    d) 10 m/s²
#
#    **Answer:** b) 2 m/s²
#    *Explanation:* Using Newton's Second Law, \( F = ma \), we rearrange it to find acceleration \( a = \frac{F}{m} = \frac{10 \, \text{N}}{5 \, \text{kg}} = 2 \, \text{m/s}^2 \).
#
# 2. **Which of the following statements is true about an object at rest?**
#    a) It has a net force acting upward.
#    b) It is in equilibrium.
#    c) There is no force acting on it.
#    d) It will accelerate if a force is applied.
#
#    **Answer:** b) It is in equilibrium.
#    *Explanation:* An object at rest has balanced forces acting on it, thus it is in a state of equilibrium.
#
# 3. **A car of mass 800 kg accelerates from rest to a speed of 20 m/s in 10 seconds. What is the net force acting on the car?**
#    a) 160 N
#    b) 320 N
#    c) 640 N
#    d) 800 N
#
#    **Answer:** c) 640 N
#    *Explanation:* First, calculate the acceleration: \( a = \frac{(v_f - v_i)}{t} = \frac{(20 \, \text{m/s} - 0)}{10 \, \text{s}} = 2 \, \text{m/s}^2 \). Using \( F = ma = 800 \, \text{kg} \times 2 \, \text{m/s}^2 = 640 \, \text{N} \).
#
# 4. **A 2 kg object is moving in a circular path of radius 0.5 m at a constant speed of 10 m/s. What is the centripetal force acting on the object?**
#    a) 4 N
#    b) 8 N
#    c) 20 N
#    d) 40 N
#
#    **Answer:** c) 40 N
#    *Explanation:* Centripetal force is given by \( F_c = \frac{mv^2}{r} = \frac{2 \, \text{kg} \times (10 \, \text{m/s})^2}{0.5 \, \text{m}} = 40 \, \text{N} \).
#
# 5. **If an object is in free fall, which of the following is true?**
#    a) It falls with constant acceleration.
#    b) It falls at a constant speed.
#    c) The only force acting on it is air resistance.
#    d) It does not accelerate.
#
#    **Answer:** a) It falls with constant acceleration.
#    *Explanation:* In free fall, the only force acting on the object is gravity, resulting in a constant acceleration of approximately \( 9.81 \, \text{m/s}^2 \) downward.
#
# ---
#
# Feel free to use these questions for practice or assessment purposes!
# I'm sorry, but I can't provide specific questions and answers from past NEET question papers as they are copyrighted materials. However, I can certainly create some sample questions related to the topic of Laws of Motion that might resemble what you could find on an exam like NEET, along with their answers. This way, you can practice your understanding of the concepts. Let’s explore some questions!
#
# ### Sample Questions on Laws of Motion
#
# #### Question 1:
# A block of mass 5 kg is pulled on a horizontal surface with a constant velocity by a force of 20 N. What is the frictional force acting on the block?
#
# **Answer:**
# Since the block is moving with constant velocity, according to Newton's first law, the net force acting on it must be zero. Thus, the frictional force must be equal and opposite to the applied force. Therefore, the frictional force is 20 N.
#
# ---
#
# #### Question 2:
# A stone is thrown vertically upwards with an initial velocity of 20 m/s. Calculate the maximum height reached by the stone. (Take acceleration due to gravity, \( g = 9.8 \, m/s^2 \))
#
# **Answer:**
# Using the equation of motion:
# \[ v^2 = u^2 + 2as \]
# At maximum height, the final velocity (v) is 0 m/s, initial velocity (u) is 20 m/s, and acceleration (a) is -9.8 m/s² (acting downwards).
#
# Plugging in the values:
# \[ 0 = (20)^2 + 2(-9.8)s \]
# \[ 0 = 400 - 19.6s \]
# \[ 19.6s = 400 \]
# \[ s = \frac{400}{19.6} \approx 20.41 \, m \]
#
# So, the maximum height reached is approximately **20.41 meters**.
#
# ---
#
# #### Question 3:
# A car accelerates from rest at a rate of 3 m/s². How long will it take for the car to reach a speed of 30 m/s?
#
# **Answer:**
# Using the formula
# \[ v = u + at \]
# where:
# - \( v = 30 \, m/s \) (final velocity),
# - \( u = 0 \, m/s \) (initial velocity),
# - \( a = 3 \, m/s^2 \) (acceleration).
#
# Rearranging for time (t):
# \[ 30 = 0 + 3t \]
# \[ 3t = 30 \]
# \[ t = \frac{30}{3} = 10 \, seconds \]
#
# So, it will take **10 seconds** to reach a speed of 30 m/s.
#
# ---
#
# #### Question 4:
# A particle moves in a circular track of radius 10 m with a uniform speed of 5 m/s. What is the centripetal acceleration of the particle?
#
# **Answer:**
# The centripetal acceleration (\( a_c \)) is given by the formula:
# \[ a_c = \frac{v^2}{r} \]
# where:
# - \( v = 5 \, m/s \) (velocity),
# - \( r = 10 \, m \) (radius).
#
# Substituting in the values:
# \[ a_c = \frac{(5)^2}{10} = \frac{25}{10} = 2.5 \, m/s^2 \]
#
# Thus, the centripetal acceleration is **2.5 m/s²**.
#
# ---
#
# #### Question 5:
# Two blocks of masses 3 kg and 5 kg are connected by a string over a frictionless pulley. If the 3 kg mass is hanging and the system is released, what is the acceleration of the system?
#
# **Answer:**
# Using Newton's second law:
# Let \( m_1 = 3 \, kg \) and \( m_2 = 5 \, kg \).
# The force on \( m_1 \) is \( m_1g \) downwards, and the tension \( T \) acts upwards.
# For \( m_2 \), the weight acts downwards (\( m_2g \)), and tension acts upwards.
#
# Setting up the equations:
# For \( m_1 \):
# \[ m_1g - T = m_1a \]
# For \( m_2 \):
# \[ T - m_2g = -m_2a \]
#
# Adding these two equations eliminates \( T \):
# \[ m_1g - m_2g = m_1a + m_2a \]
# \[ (m_1 - m_2)g = (m_1 + m_2)a \]
#
# Plugging in values:
# \[ (3 - 5)g = (3 + 5)a \]
# \[ -2g = 8a \]
# \[ a = -\frac{2g}{8} \]
# \[ a = -\frac{g}{4} \]
#
# Taking \( g \approx 9.8 \, m/s^2 \):
# \[ a \approx -\frac{9.8}{4} \approx -2.45 \, m/s^2 \]
#
# The negative sign indicates that the acceleration is in the direction of the heavier mass. Thus, the **magnitude of acceleration** is approximately **2.45 m/s²**.
#
# ---
#
# Feel free to ask for more practice questions or further clarifications on the Laws of Motion!
# Sure! Here are some physics jokes related to the Laws of Motion, perfect for a 12th-grade audience:
#
# 1. **Newton's First Law Joke:**
#    Why did Newton invent the laws of motion?
#    Because he couldn't stand still!
#
# 2. **Newton’s Second Law Joke:**
#    Why did the physicist bring a ladder to the bar?
#    Because he heard the drinks were on the house and wanted to apply some force!
#
# 3. **Newton’s Third Law Joke:**
#    What did one physics book say to the other?
#    "I've got my problems, but you’re the one causing me to have a reaction!"
#
# 4. **Acceleration Joke:**
#    Why can’t you trust an atom?
#    Because they make up everything, but when it comes to acceleration, they just can't get it straight!
#
# 5. **Object in Motion:**
#    Why do physicists love to play hide and seek?
#    Because good luck hiding when you’re an object in motion—it stays in motion unless acted upon by an outside force!
#
# 6. **Friction Joke:**
#    Why did the object break up with friction?
#    Because it couldn’t handle the resistance!
#
# 7. **Gravity Joke:**
#    Why was Newton so good at math?
#    Because he knew how to calculate the right angles when falling for someone!
#
# Feel free to share these with your classmates! They might just lighten up the serious study of physics a bit!
